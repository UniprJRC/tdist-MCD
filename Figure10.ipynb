% %% [markdown]
% # <span style="color:rgb(213,80,0)">This script generates Figure 10</span>
%
% The figure is about the estimation of the correct degrees of freedom of the data generating process \$\\hat{\\nu}\$. It implements Algorithm 2, which test the departures from the bands of various \$\\nu_0\$ candidate values. The band that keeps inside the empirical radius process, gives the right \$\\nu\$.
%
% ## Scatterplots of the bands obtained for various candidate $\nu_0$ values

% %%
rep               = 500;
n                 = 1000;
p                 = 5;
alpha0            = 0.25;

nu_true           = 5;
s                 = [3,5,8,10,20] - nu_true;

epsilon_true      = 0.10;

shift             = 10;

[nu_hat] = paper_Figure_10_test_nu0_algorithm2(...
n, p, alpha0, nu_true, s, epsilon_true, shift)
% Out:
% found 635 exceedences
% <center><img src="data:image/png;base64,..." width="265" alt="figure_0.png"></center>
% found 473 exceedences
% <center><img src="data:image/png;base64,..." width="265" alt="figure_1.png"></center>
% found 185 exceedences
% <center><img src="data:image/png;base64,..." width="265" alt="figure_2.png"></center>
% found 0 exceedences: Estimated nu = 5 and epsilon = 0.1
% <center><img src="data:image/png;base64,..." width="265" alt="figure_3.png"></center>
% found 267 exceedences
% <center><img src="data:image/png;base64,..." width="265" alt="figure_4.png"></center>
% nu_hat = 5
